# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
# Nạp dữ liệu
X = np.array([[147, 150, 153, 158, 163, 165, 168, 170, 173, 175, 178, 180, 183]]).T
y = np.array([[ 49, 50, 51, 54, 58, 59, 60, 62, 63, 64, 66, 67, 68]]).T

# %%
# Xây dựng biểu đồ
plt.plot(X, y, 'ro', color="blue")
plt.axis([140, 190, 45, 100])
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_6320\3689560602.py:2: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ro" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(X, y, 'ro', color="blue")

# %%
# Xây dựng mô hình
model = linear_model.LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
X1 = np.array([[140,190]]).T
y1 = model.predict(X1)
plt.plot(X, y, 'ro', color="blue")
plt.plot(X1, y1, color="violet")

plt.axis([140, 190, 45, 100])
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_6320\3219972561.py:3: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ro" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(X, y, 'ro', color="blue")

# %%
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_6320\388558030.py:7: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ro" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(X2, y2, 'ro', color="blue")
