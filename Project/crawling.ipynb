# %%
import requests
import csv
from bs4 import BeautifulSoup

# %%
response = requests.get("https://genk.vn/apps-games.chn")
# print(response.content)

soup = BeautifulSoup(response.content, "html.parser")
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="vi"><head><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><meta content="width=device-width, initial-scale=1, maximum-scale=5, minimal-ui" name="viewport"/><title>Tin tức Game, Mobile Apps và các ứng dụng hay dành cho bạn</title><meta content="Giới thiệu tư vấn cho bạn các ứng dụng di động Mobile Apps cực độc, cùng rất nhiều Game hay, các Games chiến thuật đình đám đang chờ bạn. Khám phá ngay...!" name="description"/><meta content="tin tức game,mobile app,ứng dụng hay,Game mobile, ứng dụng, Android, iPhone OS, game iPhone, game android, Bada, Androi Market, gameloft, game symbian, iTunes, App Store, Android Market, FPS, Angry Birds,ứng dụng, ứng dụng di động, mobile apps, game hay" name="keywords"/><meta content="" name="news_keywords"/><meta content="Tin tức Game, Mobile Apps và các ứng dụng hay dành cho bạn" property="og:title"/><meta content="Giới thiệu tư vấn cho bạn các ứng dụng di động Mobile Apps cực độc, cùng rất nhiều Game hay, các Games chiến thuật đình đám đang chờ bạn. Khám phá ngay...!" property="og:description"/><meta content="article" property="og:type"><meta content="https://genk.vn/apps-games.chn" property="og:url"><meta content="https://static.mediacdn.vn/genk/web_images/image-share-social.png" property="og:image"><meta content="image/jpg" property="og:image:type"><meta content="600" property="og:image:width"><meta content="315" property="og:image:height"/><link href="https://genk.vn/apps-games.chn" rel="canonical"/><link href="https://genk.vn/rss/apps-games.rss" rel="alternate" title="Tin tức Game, Mobile Apps và các ứng dụng hay dành cho bạn" type="application/rss+xml"/><meta content="max-image-preview:large,index, follow" name="robots"/><meta content="3600" http-equiv="refresh"/><meta content="vi" name="Language"/><meta content="Global" name="distribution"/><meta content="1 days" name="revisit-after"/><meta content="https://genk.vn" name="generator"/><meta content="IqMu_6gL8qrRWMrmEHWvHgOcIagIaCr0bGOEFogTm-s" name="google-site-verification"/><meta content="GENERAL" name="RATING"><meta content="https://genk.vn" name="site_path"/><meta content="VCCorp.vn" name="author"/><meta content="Công ty cổ phần Truyền Thông Việt Nam - Vccorp" name="copyright"><meta content="on" http-equiv="x-dns-prefetch-control"><link href="https://static.mediacdn.vn/" rel="dns-prefetch"/><link href="https://cnnd.mediacdn.vn/" rel="dns-prefetch"/><link href="https://videothumbs.mediacdn.vn/" rel="dns-prefetch"/><link href="https://videothumbs-ext.mediacdn.vn/" rel="dns-prefetch"/><link href="https://genk.mediacdn.vn/" rel="dns-prefetch"/><link href="https://m.genk.vn" media="only screen and (max-width: 640px)" rel="alternate"><link href="https://m.genk.vn" media="handheld" rel="alternate"><link href="https://genk.mediacdn.vn/web_images/genk32.png" rel="shortcut icon" type="image/png"/><link href="https://genk.mediacdn.vn/web_images/genk57.png" rel="apple-touch-icon" sizes="57x57"/><link href="https://genk.mediacdn.vn/web_images/genk60.png" rel="apple-touch-icon" sizes="60x60"/><link href="https://genk.mediacdn.vn/web_images/genk72.png" rel="apple-touch-icon" sizes="72x72"/><link href="https://genk.mediacdn.vn/web_images/genk76.png" rel="apple-touch-icon" sizes="76x76"/><link href="https://genk.mediacdn.vn/web_images/genk114.png" rel="apple-touch-icon" sizes="114x114"/><link href="https://genk.mediacdn.vn/web_images/genk120.png" rel="apple-touch-icon" sizes="120x120"/><link href="https://genk.mediacdn.vn/web_images/genk128.png" rel="apple-touch-icon" sizes="128x128"/><link href="https://genk.mediacdn.vn/web_images/genk144.png" rel="apple-touch-icon" sizes="144x144"/><link href="https://genk.mediacdn.vn/web_images/genk152.png" rel="apple-touch-icon" sizes="152x152"/><link href="https
trùm đứng sau Black Myth: Wukong: Sở hữu công ty giá trị tỷ đô, lọt danh sách 30 Under 30” của Forbes" width="260"/></a></div><div class="knswli-right elp-list"><div class="afnews-type"><a class="knswli-category" href="/apps-games.chn" title="Apps/Games">Apps/Games</a></div><h4 class="knswli-title"><a class="show-popup visit-popup" data-id="20240905085102275" data-popup-url="/lo-dien-ong-trum-dung-sau-black-myth-wukong-so-huu-cong-ty-gia-tri-ty-do-lot-danh-sach-30-under-30-cua-forbes-20240905085102275.chn" href="/lo-dien-ong-trum-dung-sau-black-myth-wukong-so-huu-cong-ty-gia-tri-ty-do-lot-danh-sach-30-under-30-cua-forbes-20240905085102275.chn" newstype="0" title="Lộ diện ông trùm đứng sau Black Myth: Wukong: Sở hữu công ty giá trị tỷ đô, lọt danh sách 30 Under 30” của Forbes">Lộ diện ông trùm đứng sau Black Myth: Wukong: Sở hữu công ty giá trị tỷ đô, lọt danh sách 30 Under 30” của Forbes</a></h4><span class="knswli-sapo">Cuối cùng, nhân vật đứng sau tựa game đình đám Black Myth: Wukong cũng đã lộ diện.</span><div class="knswli-meta"><span class="knswli-time" title="2024-09-05T08:49:00">3 tuần trước</span></div></div></li>]

# %%
titles = []
sapos = []
categories = []
for article in articles:
    for h4 in article.find_all('h4', class_='knswli-title'):
        titles.append(h4.get_text(strip=True))
    for span in article.find_all('span', class_='knswli-sapo'):
        sapos.append(span.get_text(strip=True))
    for a in article.find_all('a', class_='knswli-category'):
        categories.append(a.get_text(strip=True))

# In ra danh sách các tiêu đề
print(titles)
print(sapos)
print(categories)
# Out:
# ['Vệt kẻ trông như nét bút chì dưới móng tay lại có thể là dấu hiệu cho thấy bạn đang mắc ung thư', 'Đánh giá G.Skill TridentZ5 Royal Neo 6000MHz CL28: kit RAM DDR5 sang chảnh dành cho cấu hình AMD chơi game', 'Điện thoại này giá chỉ hơn 8 triệu có hiệu năng AnTuTu hơn 2 triệu điểm, pin khủng 6.400mAh, màn hình 144Hz', '[BCA 2024] Honda CR-V - Xe phổ thông tiêu biểu cho gia đình', '[BCA 2024] VinFast VF 6 - Xe năng lượng xanh tiên phong', "Thay đổi của Apple phá bỏ lịch sử 2 thập kỷ, 'kế sinh nhai' nhiều ứng dụng mới nổi điêu đứng", 'Long Châu, FPT AI đồng loạt ghi danh tại Better Choice Awards 2024 và Vietnam Innovation Challenge', 'Cách chặn người lạ tìm Zalo của mình bằng số điện thoại', 'Kết nối Internet từ Việt Nam đi quốc tế khôi phục hoàn toàn trong tháng này', 'OSUNO tung siêu phẩm khóa thông minh Face ID OSN-3359 "thách thức mọi tiêu chuẩn"', 'Điểm thi càng cao, giá giảm càng khủng: khi mua Laptop, PC tại Máy tính Khóa Vàng', '[BCA 2024] VinFast VF 6 - Xe quốc dân cho người mới', '[BCA 2024] Suzuki Jimny - Xe Chất chơi của năm', '[BCA 2024] VinFast VF 7 - Đột phá thiết kế trên ô tô hiện đại', '[BCA 2024] Skoda - Thương hiệu xe mới tiêu biểu', 'Top 5 smartphone có camera đỉnh của chóp đáng mua trong tầm giá 15-20 triệu', 'Có rất ít thảm thực vật trong sa mạc, vậy tại sao nó vẫn có thể hấp thụ một lượng lớn carbon dioxide?', '[BCA 2024] Volvo XC90 - Xe sang tiêu biểu cho gia đình', '[BCA 2024] VinFast VF 7 - Xe dẫn đầu xu hướng', 'Oppo K12 Plus lộ cấu hình chi tiết và thiết kế trước ngày ra mắt', 'Flagship tiếp theo của Realme sẽ có pin 6.000mAh, sạc nhanh 100W', 'Gala Better Choice Awards 2024: "Kẻ cắp trái tim" Soobin Hoàng Sơn vừa cất giọng đã bóp nghẹt trái tim người hâm mộ', 'Khám phá tổ hợp LG GROUND220, toạ độ check-in ngay giữa lòng Seoul của giới trẻ Hàn Quốc: Sống khỏe và hiện đại là như thế này!', 'Trang Pháp trình diễn liền một mạch 3 ca khúc cực sung, quay banh khán trường Gala Better Choice Awards', 'Mark Zuckerberg đã gia nhập CLB 200 tỷ USD như thế nào?']
# ['Và đó còn là loại ung thư da ác tính nhất.', 'Như tên gọi của mình, G.Skill TridentZ5 Royal Neo 6000MHz là một kit RAM có thiết kế “hoàng gia”, cao cấp bậc nhất thị trường hiện nay.', 'iQOO Z9 Turbo+ là phiên bản nâng cấp của Z9 Turbo ra mắt cách đây ít lâu. Model mới được nâng cấp về mặt hiệu năng cũng như dung lượng pin, mang tới một mức cấu hình có thể đánh giá là top đầu trên thị trường, trong khi mức giá vẫn vô cùng dễ tiếp cận, chỉ từ hơn 8 triệu đồng.', 'Sở hữu không gian rộng rãi, nhiều công nghệ an toàn, trải nghiệm vận hành hài hòa đã giúp Honda CR-V chiến thắng giải “Xe phổ thông tiêu biểu cho gia đình” nằm trong khuôn khổ giải Better Choice Awards 2024.', 'Nhờ những ưu điểm vượt trội của xe điện, VinFast VF 6 đã vượt qua hàng loạt đối thủ đồng hương đáng gờm để chiến thắng hạng mục “Xe năng lượng xanh tiên phong” tại Better Choice Awards 2024.', 'Thay đổi này trong iOS18 được cho là rất quan trọng.', 'FPT tiếp tục khẳng định vị thế trong lĩnh vực công nghệ và đổi mới sáng tạo tại Việt Nam khi được vinh danh với hàng loạt giải thưởng quan trọng tại Vietnam Innovation Challenge và Better Choice Awards.', 'Mặc định, ứng dụng chat Zalo cho phép người khác tìm tài khoản của bạn bằng cách nhập số điện thoại vào ô tìm kiếm. Nếu không muốn điều đó xảy ra, người dùng Zalo trên điện thoại thông minh có thể thiết lập bảo mật.', 'Kết nối Internet từ Việt Nam đi quốc tế trên tuyến cáp quang biển IA đã được khôi phục hoàn toàn. Với các sự cố xảy ra trên 2 tuyến cáp APG và AAE-1, đối tác quốc tế dự kiến hoàn thành việc khắc phục trong tháng 10.', 'OSUNO - Thương hiệu về khóa cửa vân tay tung ra mẫu khóa cửa vân tay Face ID OSN - 3359 với những tính năng đột phá: Mở khóa bằng nhận diện khuôn mặt 3D, pin sạc 4200 mAh, mở khóa qua App từ xa không giới hạn khoảng cách.', 'Nhằm ghi nhận nỗ lực học tập của học sinh - sinh viên, Máy Tính Khóa Vàng triển khai chương trình "Back To School 2024" với ưu đãi lên tới 1 triệu đồng khi mua Laptop tại hệ thống.', 'Nhờ những ưu điểm của xe điện kết hợp với giá trị vượt trội mang lại ở các mảng an toàn, không gian, tiện nghi và vận hành, VinFast VF 6 đã vượt qua hàng loạt đối thủ sừng sỏ để chiến thắng hạng mục “Xe quốc dân cho người mới” tại Better Choice Awards 2024.', 'Thiết kế ấn tượng, tính cá nhân hoá cao và tầm ảnh hưởng trong giới chơi xe, Suzuki Jimny đã đã chiến thắng hạng mục “Xe Chất chơi của năm” tại Better Choice Awards 2024.', 'Sở hữu thiết kế coupe SUV hiện đại được chắp bút bởi studio danh tiếng Torino Design, đậm chất thể thao, VinFast VF 7 đã chiến thắng hạng mục “Đột phá thiết kế trên ô tô hiện đại” tại Better Choice Awards 2024.', 'Sở hữu dải sản phẩm chất lượng, kênh bán hàng bài bản và nhà phân phối uy tín, Skoda đã chiến thắng hạng mục “Thương hiệu xe mới tiêu biểu” tại Better Choice Awards 2024.', 'Với ống kính Leica cao cấp cùng với nhiều trang bị ấn tượng, Xiaomi 14T Pro khiến ngay cả những smartphone đắt tiền hơn cũng phải e dè.', 'Sa mạc, với vẻ ngoài khô cằn, ít thảm thực vật và khí hậu khắc nghiệt, từ lâu đã được coi là những vùng đất hoang sơ không mấy giá trị. Tuy nhiên, nếu ta nhìn kỹ hơn vào những khía cạnh tiềm ẩn, sa mạc lại đóng vai trò quan trọng trong sự phát triển bền vững của Trái Đất.', 'Sang trọng, hiện đại, rộng rãi và đặc biệt an toàn, Volvo XC90 đã chiến thắng hạng mục “Xe sang tiêu biểu cho gia đình” tại Better Choice Awards 2024.', 'Sở hữu thiết kế coupe SUV hiện đại, đậm chất thể thao cùng trải nghiệm lái mạnh mẽ như xe hiệu suất cao, VinFast VF 7 đã chiến thắng hạng mục “Xe dẫn đầu xu hướng” tại Better Choice Awards 2024.', 'Oppo đang phát triển smartphone dòng K mới cho thị trường Trung Quốc với tên gọi dự kiến là Oppo K12 Plus.', 'Realme GT 7 Pro dự kiến ra mắt đầu tháng 11 sở hữu viên pin lớn nhất mà hãng từng trang bị cho smartphone của mình.', 'Sự xuất hiện của Soobin Hoàng Sơn tại Gala Better Choice Awards 2024 khiến khán giả phấn khích.', 'Trong nỗ lực trở thành “Công ty giải pháp cuộc sống thông minh”, LG đã làm mới khu trải nghiệm sản p ...
# ['Sống', 'Đồ chơi số', 'Mobile', 'Xe', 'Xe', 'Tin ICT', 'Tin ICT', 'Thủ thuật', 'Tin ICT', 'Xem - Mua - Luôn', 'Xem - Mua - Luôn', 'Xe', 'Xe', 'Xe', 'Xe', 'Mobile', 'Sống', 'Xe', 'Xe', 'Mobile', 'Mobile', 'Sống', 'Sống', 'Sống', 'Trà đá công nghệ']

# %%
articles_data = []

for article in articles:
    # Tạo một dictionary cho mỗi bài viết
    article_data = {}

    # Lấy tiêu đề
    title = article.find('h4', class_='knswli-title')
    if title:
        article_data['title'] = title.get_text(strip=True)
    else:
        article_data['title'] = None

    # Lấy sapo
    sapo = article.find('span', class_='knswli-sapo')
    if sapo:
        article_data['sapo'] = sapo.get_text(strip=True)
    else:
        article_data['sapo'] = None

    # Lấy category
    category = article.find('a', class_='knswli-category')
    if category:
        article_data['category'] = category.get_text(strip=True)
    else:
        article_data['category'] = None

    # Thêm dictionary của bài viết vào danh sách
    articles_data.append(article_data)

print(len(articles_data))

# In ra danh sách kết quả
for data in articles_data:
    print(data)
# Out:
# 25
# {'title': 'Vệt kẻ trông như nét bút chì dưới móng tay lại có thể là dấu hiệu cho thấy bạn đang mắc ung thư', 'sapo': 'Và đó còn là loại ung thư da ác tính nhất.', 'category': 'Sống'}
# {'title': 'Đánh giá G.Skill TridentZ5 Royal Neo 6000MHz CL28: kit RAM DDR5 sang chảnh dành cho cấu hình AMD chơi game', 'sapo': 'Như tên gọi của mình, G.Skill TridentZ5 Royal Neo 6000MHz là một kit RAM có thiết kế “hoàng gia”, cao cấp bậc nhất thị trường hiện nay.', 'category': 'Đồ chơi số'}
# {'title': 'Điện thoại này giá chỉ hơn 8 triệu có hiệu năng AnTuTu hơn 2 triệu điểm, pin khủng 6.400mAh, màn hình 144Hz', 'sapo': 'iQOO Z9 Turbo+ là phiên bản nâng cấp của Z9 Turbo ra mắt cách đây ít lâu. Model mới được nâng cấp về mặt hiệu năng cũng như dung lượng pin, mang tới một mức cấu hình có thể đánh giá là top đầu trên thị trường, trong khi mức giá vẫn vô cùng dễ tiếp cận, chỉ từ hơn 8 triệu đồng.', 'category': 'Mobile'}
# {'title': '[BCA 2024] Honda CR-V - Xe phổ thông tiêu biểu cho gia đình', 'sapo': 'Sở hữu không gian rộng rãi, nhiều công nghệ an toàn, trải nghiệm vận hành hài hòa đã giúp Honda CR-V chiến thắng giải “Xe phổ thông tiêu biểu cho gia đình” nằm trong khuôn khổ giải Better Choice Awards 2024.', 'category': 'Xe'}
# {'title': '[BCA 2024] VinFast VF 6 - Xe năng lượng xanh tiên phong', 'sapo': 'Nhờ những ưu điểm vượt trội của xe điện, VinFast VF 6 đã vượt qua hàng loạt đối thủ đồng hương đáng gờm để chiến thắng hạng mục “Xe năng lượng xanh tiên phong” tại Better Choice Awards 2024.', 'category': 'Xe'}
# {'title': "Thay đổi của Apple phá bỏ lịch sử 2 thập kỷ, 'kế sinh nhai' nhiều ứng dụng mới nổi điêu đứng", 'sapo': 'Thay đổi này trong iOS18 được cho là rất quan trọng.', 'category': 'Tin ICT'}
# {'title': 'Long Châu, FPT AI đồng loạt ghi danh tại Better Choice Awards 2024 và Vietnam Innovation Challenge', 'sapo': 'FPT tiếp tục khẳng định vị thế trong lĩnh vực công nghệ và đổi mới sáng tạo tại Việt Nam khi được vinh danh với hàng loạt giải thưởng quan trọng tại Vietnam Innovation Challenge và Better Choice Awards.', 'category': 'Tin ICT'}
# {'title': 'Cách chặn người lạ tìm Zalo của mình bằng số điện thoại', 'sapo': 'Mặc định, ứng dụng chat Zalo cho phép người khác tìm tài khoản của bạn bằng cách nhập số điện thoại vào ô tìm kiếm. Nếu không muốn điều đó xảy ra, người dùng Zalo trên điện thoại thông minh có thể thiết lập bảo mật.', 'category': 'Thủ thuật'}
# {'title': 'Kết nối Internet từ Việt Nam đi quốc tế khôi phục hoàn toàn trong tháng này', 'sapo': 'Kết nối Internet từ Việt Nam đi quốc tế trên tuyến cáp quang biển IA đã được khôi phục hoàn toàn. Với các sự cố xảy ra trên 2 tuyến cáp APG và AAE-1, đối tác quốc tế dự kiến hoàn thành việc khắc phục trong tháng 10.', 'category': 'Tin ICT'}
# {'title': 'OSUNO tung siêu phẩm khóa thông minh Face ID OSN-3359 "thách thức mọi tiêu chuẩn"', 'sapo': 'OSUNO - Thương hiệu về khóa cửa vân tay tung ra mẫu khóa cửa vân tay Face ID OSN - 3359 với những tính năng đột phá: Mở khóa bằng nhận diện khuôn mặt 3D, pin sạc 4200 mAh, mở khóa qua App từ xa không giới hạn khoảng cách.', 'category': 'Xem - Mua - Luôn'}
# {'title': 'Điểm thi càng cao, giá giảm càng khủng: khi mua Laptop, PC tại Máy tính Khóa Vàng', 'sapo': 'Nhằm ghi nhận nỗ lực học tập của học sinh - sinh viên, Máy Tính Khóa Vàng triển khai chương trình "Back To School 2024" với ưu đãi lên tới 1 triệu đồng khi mua Laptop tại hệ thống.', 'category': 'Xem - Mua - Luôn'}
# {'title': '[BCA 2024] VinFast VF 6 - Xe quốc dân cho người mới', 'sapo': 'Nhờ những ưu điểm của xe điện kết hợp với giá trị vượt trội mang lại ở các mảng an toàn, không gian, tiện nghi và vận hành, VinFast VF 6 đã vượt qua hàng loạt đối thủ sừng sỏ để chiến thắng hạng mục “Xe quốc dân cho người mới” tại Better Choice Awards 2024.', 'category': 'Xe'}
# {'title': '[BCA 2024] Suzuki Jimny - Xe Chất chơi của năm', 'sapo': 'Thiết kế ấn tượng, tính cá nhân hoá cao và tầm ảnh hưởng trong giới chơi xe, Suzuki Jimny đã đã chiến thắng hạng mục “Xe Chất chơi của năm” tại Better Choice Awards 2024.', 'category': 'Xe'}
# {'title': '[BCA 2024] VinFast VF 7 - Đột phá thiết kế trên ô tô hiện đại', 'sapo': 'Sở hữu thiết kế coupe SUV hiện đại được chắp bút bởi studio danh tiếng Torino Design, đậm chất thể thao, VinFast VF 7 đã chiến thắng hạng mục “Đột phá thiết kế trên ô tô hiện đại” tại Better Choice Awards 2024.', 'category': 'Xe'}
# {'title': '[BCA 2024] Skoda - Thương hiệu xe mới tiêu biểu', 'sapo': 'Sở hữu dải sản phẩm chất lượng, kênh bán hàng bài bản và nhà phân phối uy tín, Skoda đã chiến thắng hạng mục “Thương hiệu xe mới tiêu biểu” tại Better Choice Awards 2024.', 'category': 'Xe'}
# {'title': 'Top 5 smartphone có camera đỉnh của chóp đáng mua trong tầm giá 15-20 triệu', 'sapo': 'Với ống kính Leica cao cấp cùng với nhiều trang bị ấn tượng, Xiaomi 14T Pro khiến ngay cả những smartphone đắt tiền hơn cũng phải e dè.', 'category': 'Mobile'}
# {'title': 'Có rất ít thảm thực vật trong sa mạc, vậy tại sao nó vẫn có thể hấp thụ một lượng lớn carbon dioxide?', 'sapo': 'Sa mạc, với vẻ ngoài khô cằn, ít thảm thực vật và khí hậu khắc nghiệt, từ lâu đã được coi là những vùng đất hoang sơ không mấy giá trị. Tuy nhiên, nếu ta nhìn kỹ hơn vào những khía cạnh tiềm ẩn, sa mạc lại đóng vai trò quan trọng trong sự phát triển bền vững của Trái Đất.', 'category': 'Sống'}
# {'title': '[BCA 2024] Volvo XC90 - Xe sang tiêu biểu cho gia đình', 'sapo': 'Sang trọng, hiện đại, rộng rãi và đặc biệt an toàn, Volvo XC90 đã chiến thắng hạng mục “Xe sang tiêu biểu cho gia đình” tại Better Choice Awards 2024.', 'category': 'Xe'}
# {'title': '[BCA 2024] VinFast VF 7 - Xe dẫn đầu xu hướng', 'sapo': 'Sở hữu thiết kế coupe SUV hiện đại, đậm chất thể thao cùng trải nghiệm lái mạnh mẽ như xe hiệu suất cao, VinFast VF 7 đã chiến thắng hạng mục “Xe dẫn đầu xu hướng” tại Better Choice Awards 2024.', 'category': 'Xe'}
# {'title': 'Oppo K12 Plus lộ cấu hình chi tiết và thiết kế trước ngày ra mắt', 'sapo': 'Oppo đang phát triển smartphone dòng K mới cho thị trường Trung Quốc với tên gọi dự kiến là Oppo K12 Plus.', 'category': 'Mobile'}
# {'title': 'Flagship tiếp theo của Realme sẽ có pin 6.000mAh, sạc nhanh 100W', 'sapo': 'Realme GT 7 Pro dự kiến ra mắt đầu tháng 11 sở hữu viên pin lớn nhất mà hãng từng trang bị cho smartphone của mình.', 'category': 'Mobile'}
# {'title': 'Gala Better Choice Awards 2024: "Kẻ cắp trái tim" Soobin Hoàng Sơn vừa cất giọng đã bóp nghẹt trái tim người hâm mộ', 'sapo': 'Sự xuất hiện của Soobin Hoàng Sơn tại Gala Better Choice Awards 2024 khiến khán giả phấn khích.', 'category': 'Sống'}
# {'title': 'Khám phá tổ hợp LG GROUND220, toạ độ check-in ngay giữa lòng Seoul của giới trẻ Hàn Quốc: Sống khỏe và hiện đại là như thế này!', 'sapo': 'Trong nỗ lực trở thành “Công ty giải pháp cuộc sống thông minh”, LG đã làm mới khu trải nghiệm sản phẩm để mang lại sự vui vẻ và gần gũi hơn với nhu cầu thực tế của người dùng.', 'category': 'Sống'}
# {'title': 'Trang Pháp trình diễn liền một mạch 3 ca khúc cực sung, quay banh khán trường Gala Better Choice Awards', 'sapo': 'Trang Pháp mang tới Gala Better Choice Awards 2024 những màn trình diễn cực ấn tượng.', 'category': 'Sống'}
# {'title': 'Mark Zuckerberg đã gia nhập CLB 200 tỷ USD như thế nào?', 'sapo': 'VTV.vn - Ông chủ Meta, Mark Zuckerberg vừa tiến thêm một bước nữa trên con đường tăng tốc khối tài sản của chính mình khi gia nhập CLB những tỷ phú sở hữu 200 tỷ USD.', 'category': 'Trà đá công nghệ'}

# %%
import csv

# Danh sách lưu dữ liệu bài viết
articles_data = []

# Duyệt qua các bài viết và thu thập thông tin
for index, article in enumerate(articles, start=1):
    # Tạo một dictionary cho mỗi bài viết
    article_data = {}

    # Lấy số thứ tự
    article_data['index'] = index

    # Lấy tiêu đề
    title = article.find('h4', class_='knswli-title')
    if title:
        article_data['title'] = title.get_text(strip=True)
    else:
        article_data['title'] = None

    # Lấy sapo
    sapo = article.find('span', class_='knswli-sapo')
    if sapo:
        article_data['sapo'] = sapo.get_text(strip=True)
    else:
        article_data['sapo'] = None

    # Lấy category
    category = article.find('a', class_='knswli-category')
    if category:
        article_data['category'] = category.get_text(strip=True)
    else:
        article_data['category'] = None

    # Thêm dictionary của bài viết vào danh sách
    articles_data.append(article_data)

# Lưu dữ liệu vào file CSV
csv_file = "data.csv"
with open(csv_file, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.DictWriter(file, fieldnames=['index', 'title', 'sapo', 'category'])
    writer.writeheader()
    writer.writerows(articles_data)

print(f"Đã lưu {len(articles_data)} bài viết vào file {csv_file}")
# Out:
# Đã lưu 23 bài viết vào file data.csv

# %%
import time
import json
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager

def crawl_genk_mobile():
    url = "https://genk.vn/xem-mua-luon.chn"
    max_articles = 2000  # Số lượng bài viết muốn cào
    
    # Khởi tạo trình duyệt Chrome với Selenium
    options = webdriver.ChromeOptions()
    options.add_argument("--headless")  # Chạy Chrome ở chế độ ẩn (không hiện cửa sổ trình duyệt)
    options.add_argument("--disable-gpu")
    driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)
    
    # Mở trang web
    driver.get(url)
    
    # Cuộn xuống trang web để tải thêm dữ liệu
    last_height = driver.execute_script("return document.body.scrollHeight")
    news_list = []  # Danh sách để lưu dữ liệu bài viết

    while len(news_list) < max_articles:
        # Nhấp vào nút "Xem thêm" nếu tìm thấy
        try:
            # Tìm nút "Xem thêm"
            xem_them_button = driver.find_element(By.XPATH, "//a[contains(text(), 'Xem thêm')]")
            driver.execute_script("arguments[0].click();", xem_them_button)
            time.sleep(4)  # Chờ nội dung tải thêm
        except Exception as e:
            # Nếu không tìm thấy nút "Xem thêm", tiếp tục cuộn
            pass

        # Cuộn xuống dưới cùng của trang
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        
        # Chờ trang tải thêm nội dung (thời gian có thể điều chỉnh)
        time.sleep(2)
        
        # Lấy nội dung trang hiện tại sau khi đã cuộn hoặc nhấp "Xem thêm"
        page_source = driver.page_source
        soup = BeautifulSoup(page_source, "html.parser")
        articles = soup.find_all('li', class_='knswli')

        # Duyệt qua các bài viết để lấy thông tin mới
        for article in articles[len(news_list):]:  # Chỉ duyệt qua các bài viết chưa cào
            title_tag = article.find('h4', class_='knswli-title')
            subtitle_tag = article.find('span', class_='knswli-sapo')
            category_tag = article.find('a', class_='knswli-category')
            time_tag = article.find('span', class_='knswli-time')

            # Lấy title, subtitle và chủ đề nếu có
            title = title_tag.get_text(strip=True) if title_tag else 'No title'
            subtitle = subtitle_tag.get_text(strip=True) if subtitle_tag else 'No subtitle'
            category = category_tag.get_text(strip=True) if category_tag else 'No category'
            datetime = time_tag.get_text(strip=True) if time_tag else 'No time'

            # Tạo dictionary cho bài viết
            news_item = {
                'title': title,
                'subtitle': subtitle,
                'category': category,
                'time': datetime
            }
            
            # Thêm vào danh sách các bài viết
            news_list.append(news_item)
            
            # Kiểm tra số lượng bài viết đã thu thập được
            if len(news_list) >= max_articles:
                break
        
        # Tính chiều cao mới của trang và kiểm tra nếu không có thay đổi
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break  # Dừng cuộn nếu không có thêm nội dung mới
        last_height = new_height
    
    # Đóng trình duyệt
    driver.quit()
    
    # Lưu dữ liệu vào file JSON
    with open('genk_xem_mua_luon.json', 'w', encoding='utf-8') as json_file:
        json.dump(news_list[:max_articles], json_file, ensure_ascii=False, indent=4)

    print(f"Lưu dữ liệu thành công! Đã lưu {len(news_list[:max_articles])} bản tin vào genk_xem_mua_luon.json")

# Gọi hàm để cào dữ liệu
crawl_genk_mobile()
# Out:
# Lưu dữ liệu thành công! Đã lưu 1548 bản tin vào genk_xem_mua_luon.json
